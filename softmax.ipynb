# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
arr_number=np.random.randint(1,10,50) # create a random number
soft_maxNum=sofmax=np.exp(arr_number)/np.sum(np.exp(arr_number)) # logic of softmax e^=2.7*x
plt.plot(arr_number,soft_maxNum)
